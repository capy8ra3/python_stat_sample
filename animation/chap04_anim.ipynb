# %% [markdown]
# # 推測統計の基本

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as ani
from IPython.display import HTML

# %precision 3
# %matplotlib inline

# %%
df = pd.read_csv('../data/ch4_scores400.csv')
scores = np.array(df['点数'])

dice = [1, 2, 3, 4, 5, 6]
prob = [1/21, 2/21, 3/21, 4/21, 5/21, 6/21]

# %% [markdown]
# ## 図4.3 試行回数を変化させたときの出目のヒストグラム

# %%
num_frame = 50
space = np.logspace(2, 5, num_frame).astype(int)
sample = np.random.choice(dice, size=100000, p=prob)

def animate(nframe):
    num_trial = space[nframe]
    ax.clear()
    ax.hist(sample[:num_trial], bins=6, range=(1, 7), density=True, rwidth=0.8)
    ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray')
    ax.set_title(f'試行回数:{num_trial}')
    ax.set_xticks(np.linspace(1.5, 6.5, 6))
    ax.set_xticklabels(np.arange(1, 7))
    ax.set_ylim(0, 0.3)
    ax.set_xlabel('出目', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# ...
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/3044643536.py:20: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img32d6fdc1f73440c8a4324ba8295d9725">
#   <div class="anim-controls">
#     <input id="_anim_slider32d6fdc1f73440c8a4324ba8295d9725" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim32d6fdc1f73440c8a4324ba8295d9725.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim32d6fdc1f73440c8a4324ba8295d9725.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select32d6fdc1f73440c8a4324ba8295d9725"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_32d6fdc1f73440c8a4324ba8295d9725"
#              >
#       <label for="_anim_radio1_32d6fdc1f73440c8a4324ba8295d9725">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_32d6fdc1f73440c8a4324ba8295d9725"
#              checked>
#       <label for="_anim_radio2_32d6fdc1f73440c8a4324ba8295d9725">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_32d6fdc1f73440c8a4324ba8295d9725"
#              >
#       <label for="_anim_radio3_32d6fdc1f73440c8a4324ba8295d9725">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img32d6fdc1f73440c8a4324ba8295d9725";
#     var slider_id = "_anim_slider32d6fdc1f73440c8a4324ba8295d9725";
#     var loop_select_id = "_anim_loop_select32d6fdc1f73440c8a4324ba8295d9725";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy80BEi2AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAxCklEQ

# %% [markdown]
# ## 図4.5 無作為抽出で得た標本データのヒストグラム

# %%
np.random.seed(0)
sample = np.random.choice(scores, 10000)
num_frame = 50
space = np.logspace(1, 4, num_frame).astype(int)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
def animate(nframe):
    num_sample = space[nframe]
    ax.clear()
    ax.hist(sample[:num_sample], bins=100, range=(0, 100), density=True)
    ax.set_xlabel('点数', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    ax.set_title(f'サンプルサイズ：{num_sample}')
    ax.set_xlim(20, 100)
    
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 12469 (\N{KATAKANA LETTER SA}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 12531 (\N{KATAKANA LETTER N}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 12503 (\N{KATAKANA LETTER PU}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 12523 (\N{KATAKANA LETTER RU}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 12474 (\N{KATAKANA LETTER ZU}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 65306 (\N{FULLWIDTH COLON}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/4174270583.py:18: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img6fb8d0fa83f840418ef824c877bc7983">
#   <div class="anim-controls">
#     <input id="_anim_slider6fb8d0fa83f840418ef824c877bc7983" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim6fb8d0fa83f840418ef824c877bc7983.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim6fb8d0fa83f840418ef824c877bc7983.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim6fb8d0fa83f840418ef824c877bc7983.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim6fb8d0fa83f840418ef824c877bc7983.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim6fb8d0fa83f840418ef824c877bc7983.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim6fb8d0fa83f840418ef824c877bc7983.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim6fb8d0fa83f840418ef824c877bc7983.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim6fb8d0fa83f840418ef824c877bc7983.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim6fb8d0fa83f840418ef824c877bc7983.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim6fb8d0fa83f840418ef824c877bc7983.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select6fb8d0fa83f840418ef824c877bc7983"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_6fb8d0fa83f840418ef824c877bc7983"
#              >
#       <label for="_anim_radio1_6fb8d0fa83f840418ef824c877bc7983">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_6fb8d0fa83f840418ef824c877bc7983"
#              checked>
#       <label for="_anim_radio2_6fb8d0fa83f840418ef824c877bc7983">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_6fb8d0fa83f840418ef824c877bc7983"
#              >
#       <label for="_anim_radio3_6fb8d0fa83f840418ef824c877bc7983">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6fb8d0fa83f840418ef824c877bc7983";
#     var slider_id = "_anim_slider6fb8d0fa83f840418ef824c877bc7983";
#     var loop_select_id = "_anim_loop_select6fb8d0fa83f840418ef824c877bc7983";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy80BEi2AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAxFUlEQ

# %% [markdown]
# ## 図4.6 標本平均の分布

# %%
np.random.seed(0)
sample_means = [np.random.choice(scores, 20).mean() for _ in range(10000)]

num_frame = 50
space = np.logspace(1, 4, num_frame).astype(int)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

def animate(nframe):
    num_trial = space[nframe]
    ax.clear()
    prob, _, _ = ax.hist(sample_means[:num_trial],
                         bins=100, range=(0, 100), density=True)
    ax.vlines(np.mean(scores), 0, 1, 'gray')
    ax.set_title(f'試行回数：{num_trial}')
    ax.set_xlabel('点数', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    ax.set_xlim(50, 90)
    ax.set_ylim(0, prob.max() * 1.1)
    
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 23550 (\N{CJK UNIFIED IDEOGRAPH-5BFE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 35430 (\N{CJK UNIFIED IDEOGRAPH-8A66}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 65306 (\N{FULLWIDTH COLON}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# /var/folders/w1/ybmrrtt57bbfsqj1yc0cv2840000gn/T/ipykernel_15342/1916725138.py:23: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from font(s) DejaVu Sans.
#   js_anim = HTML(anim.to_jshtml())
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5ef6426671364fd0a186d4f6c785cf62">
#   <div class="anim-controls">
#     <input id="_anim_slider5ef6426671364fd0a186d4f6c785cf62" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5ef6426671364fd0a186d4f6c785cf62.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim5ef6426671364fd0a186d4f6c785cf62.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim5ef6426671364fd0a186d4f6c785cf62.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim5ef6426671364fd0a186d4f6c785cf62.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim5ef6426671364fd0a186d4f6c785cf62.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim5ef6426671364fd0a186d4f6c785cf62.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim5ef6426671364fd0a186d4f6c785cf62.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim5ef6426671364fd0a186d4f6c785cf62.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim5ef6426671364fd0a186d4f6c785cf62.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim5ef6426671364fd0a186d4f6c785cf62.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select5ef6426671364fd0a186d4f6c785cf62"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5ef6426671364fd0a186d4f6c785cf62"
#              >
#       <label for="_anim_radio1_5ef6426671364fd0a186d4f6c785cf62">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5ef6426671364fd0a186d4f6c785cf62"
#              checked>
#       <label for="_anim_radio2_5ef6426671364fd0a186d4f6c785cf62">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5ef6426671364fd0a186d4f6c785cf62"
#              >
#       <label for="_anim_radio3_5ef6426671364fd0a186d4f6c785cf62">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5ef6426671364fd0a186d4f6c785cf62";
#     var slider_id = "_anim_slider5ef6426671364fd0a186d4f6c785cf62";
#     var loop_select_id = "_anim_loop_select5ef6426671364fd0a186d4f6c785cf62";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy80BEi2AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAylUlEQ
